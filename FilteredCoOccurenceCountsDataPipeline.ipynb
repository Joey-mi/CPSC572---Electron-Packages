# %% [markdown]
# <a href="https://colab.research.google.com/github/Joey-mi/CPSC572---Electron-Packages/blob/main/FilteredCoOccurenceCountsDataPipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview
#
# Take the total co-occurrences, sort them, and filter them

# %%
# Link Google Drive data to this colab session
from google.colab import drive
drive.mount('/content/drive')

# Bring in important imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Create a dataframe of the total co-occurences
totalDF = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCounts.csv", sep="\t", dtype={'Dependency Pair': str, 'Co-Occurences': 'Int64'})
display(totalDF)
# Out:
#                                 Dependency Pair  Co-Occurences
# 0                           node-sass@react-dom             99
# 1                        devtron@electron-debug             99
# 2                                 jquery@lodash             99
# 3                                mobx@react-dom             99
# 4               font-awesome@react-router-redux             99
# ...                                         ...            ...
# 134987                              qrcode@uuid             10
# 134988    codemirror/commands@codemirror/gutter             10
# 134989   codemirror/commands@codemirror/history             10
# 134990  codemirror/commands@codemirror/language             10
# 134991                   jszip@react-router-dom             10
#
# [134992 rows x 2 columns]

# %%
# Aggregate similar rows
d = {'Co-Occurences': 'sum'}
df_new = totalDF.groupby('Dependency Pair', as_index=False).aggregate(d).reindex(columns=totalDF.columns)

# Sort desc by co-occurrences
sortedDF = df_new.sort_values(['Co-Occurences'], ascending=[False])
display(sortedDF)
# Out:
#                    Dependency Pair  Co-Occurences
# 110003             react@react-dom           2788
# 110193      react@react-router-dom           1171
# 105005  react-dom@react-router-dom           1170
# 126724              vue@vue-router            915
# 70454            history@react-dom            781
# ...                            ...            ...
# 31353     cookie-parser@prop-types              2
# 31352            cookie-parser@pm2              2
# 31351       cookie-parser@platform              2
# 31349        cookie-parser@perdido              2
# 0                   7zip-bin@axios              2
#
# [127748 rows x 2 columns]

# %%
#Find dict...
dictWhere = totalDF[(totalDF['Dependency Pair'].str.contains("dict") == True)]
display(dictWhere)
# Out:
# Empty DataFrame
# Columns: [Dependency Pair, Co-Occurences]
# Index: []

# %%
# Save as a CSV
import os

filename = "coOccurenceCountsAggregated.csv"

sortedDF.to_csv('/content/drive/MyDrive/CPSC 572 Project/Data/' + filename, sep='\t', index=False)
if os.path.isfile('/content/drive/MyDrive/CPSC 572 Project/Data/' + filename):
  print(f"Successfully uploaded {filename} to /content/drive/MyDrive/CPSC 572 Project/Data/")
else:
  print(f"ERROR: Download unsuccessful for {filename} to /content/drive/MyDrive/CPSC 572 Project/Data/")

# %%
# List words to filter out
common1 = "react"
common2 = "electron"
common3 = "vue"
common4 = "angular"
common5 = "testing"
occurrence = 1 # 1 to filter common words out completely, 2 to filter rows where they are paired with each other, 3 for no filter

attemptFilter = sortedDF[(sortedDF['Dependency Pair'].str.count(common1) < occurrence)
& (sortedDF['Dependency Pair'].str.count(common2) < occurrence)
& (sortedDF['Dependency Pair'].str.count(common3) < occurrence)
& (sortedDF['Dependency Pair'].str.count(common4) < occurrence)
& (sortedDF['Dependency Pair'].str.count(common5) < occurrence)]
display(attemptFilter.head(25))
# Out:
#                                           Dependency Pair  Co-Occurences
# 70570                                       history@redux            482
# 111602                                  redux@redux-thunk            447
# 70644                          history@source-map-support            434
# 70589                                 history@redux-thunk            409
# 113437                                       rxjs@zone.js            359
# 21170                                    bootstrap@jquery            303
# 111666                           redux@source-map-support            224
# 70592                         history@regenerator-runtime            222
# 32314                                        core-js@rxjs            217
# 111467                     redux-thunk@source-map-support            211
# 12640                                        axios@lodash            206
# 32563                                     core-js@zone.js            202
# ...

# %%
# Save as a CSV
import os

filename = "coOccurenceCountsFiltered.csv"

attemptFilter.to_csv('/content/drive/MyDrive/CPSC 572 Project/Data/' + filename, sep='\t', index=False)
if os.path.isfile('/content/drive/MyDrive/CPSC 572 Project/Data/' + filename):
  print(f"Successfully uploaded {filename} to /content/drive/MyDrive/CPSC 572 Project/Data/")
else:
  print(f"ERROR: Download unsuccessful for {filename} to /content/drive/MyDrive/CPSC 572 Project/Data/")
# Out:
# Successfully uploaded coOccurenceCountsFiltered.csv to /content/drive/MyDrive/CPSC 572 Project/Data/

# %%
# Run a test case of combining TF-IDF identified packages with co-occurrences
demo = sortedDF[(sortedDF['Dependency Pair'].str.count('nivo') < 2) & (sortedDF['Dependency Pair'].str.contains('nivo')==True)]
display(demo.head(15))
# Out:
#                   Dependency Pair  Co-Occurences
# 93971              nivo/pie@react              5
# 93975          nivo/pie@react-dom              5
# 93987  nivo/pie@styled-components              4
# 93968             nivo/pie@moment              4
# 93902             nivo/bar@moment              3
# 93941             nivo/core@react              3
# 93905              nivo/bar@react              3
# 93907          nivo/bar@react-dom              3
# 93918  nivo/bar@styled-components              3
# 93927         nivo/calendar@react              3
# 93928     nivo/calendar@react-dom              3
# 93942         nivo/core@react-dom              3
# 93963   nivo/pie@electron-updater              3
# 93977        nivo/pie@react-redux              3
# 93978   nivo/pie@react-router-dom              3
