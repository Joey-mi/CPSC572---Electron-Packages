# %% [markdown]
# <a href="https://colab.research.google.com/github/Joey-mi/CPSC572---Electron-Packages/blob/main/Co_OccurrenceCountPipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview
#
# See how often dependencies occur together by aggregating the results from the Hadoop MapReduce computation.
#
# Then save as csv.

# %%
# Link Google Drive data to this colab session
from google.colab import drive
drive.mount('/content/drive')

# Bring in important imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %%
# Create a dataframe of each count file
dataframe00 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00000.txt", sep=", ", header=None, dtype=str)
dataframe01 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00001.txt", sep=", ", header=None, dtype=str)
dataframe02 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00002.txt", sep=", ", header=None, dtype=str)
dataframe03 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00003.txt", sep=", ", header=None, dtype=str)
dataframe04 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00004.txt", sep=", ", header=None, dtype=str)
dataframe05 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00005.txt", sep=", ", header=None, dtype=str)
dataframe06 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00006.txt", sep=", ", header=None, dtype=str)
dataframe07 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00007.txt", sep=", ", header=None, dtype=str)
dataframe08 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00008.txt", sep=", ", header=None, dtype=str)
dataframe09 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00009.txt", sep=", ", header=None, dtype=str)
dataframe10 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00010.txt", sep=", ", header=None, dtype=str)
dataframe11 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00011.txt", sep=", ", header=None, dtype=str)
dataframe12 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00012.txt", sep=", ", header=None, dtype=str)
dataframe13 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00013.txt", sep=", ", header=None, dtype=str)
dataframe14 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00014.txt", sep=", ", header=None, dtype=str)
dataframe15 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00015.txt", sep=", ", header=None, dtype=str)
dataframe16 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00016.txt", sep=", ", header=None, dtype=str)
dataframe17 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00017.txt", sep=", ", header=None, dtype=str)
dataframe18 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00018.txt", sep=", ", header=None, dtype=str)
dataframe19 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00019.txt", sep=", ", header=None, dtype=str)
dataframe20 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00020.txt", sep=", ", header=None, dtype=str)
dataframe21 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00021.txt", sep=", ", header=None, dtype=str)
dataframe22 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00022.txt", sep=", ", header=None, dtype=str)
dataframe23 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00023.txt", sep=", ", header=None, dtype=str)
dataframe24 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00024.txt", sep=", ", header=None, dtype=str)
dataframe25 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00025.txt", sep=", ", header=None, dtype=str)
# Out:
# <ipython-input-20-0b03f11f023e>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   dataframe00 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00000.txt", sep=", ", header=None, dtype=str)
# <ipython-input-20-0b03f11f023e>:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   dataframe01 = pd.read_csv("/content/drive/MyDrive/CPSC 572 Project/Data/coOccurenceCount/part-00001.txt", sep=", ", header=None, dtype=str)
# ...

# %%
# Concatenate all the dataframes together:
mergeDF00 = pd.concat([dataframe00, dataframe00])
mergeDF01 = pd.concat([mergeDF00, dataframe01])
mergeDF02 = pd.concat([mergeDF01, dataframe02])
mergeDF03 = pd.concat([mergeDF02, dataframe03])
mergeDF04 = pd.concat([mergeDF03, dataframe04])
mergeDF05 = pd.concat([mergeDF04, dataframe05])
mergeDF06 = pd.concat([mergeDF05, dataframe06])
mergeDF07 = pd.concat([mergeDF06, dataframe07])
mergeDF08 = pd.concat([mergeDF07, dataframe08])
mergeDF09 = pd.concat([mergeDF08, dataframe09])
mergeDF10 = pd.concat([mergeDF09, dataframe10])
mergeDF11 = pd.concat([mergeDF10, dataframe11])
mergeDF12 = pd.concat([mergeDF11, dataframe12])
mergeDF13 = pd.concat([mergeDF12, dataframe13])
mergeDF14 = pd.concat([mergeDF13, dataframe14])
mergeDF15 = pd.concat([mergeDF14, dataframe15])
mergeDF16 = pd.concat([mergeDF15, dataframe16])
mergeDF17 = pd.concat([mergeDF16, dataframe17])
mergeDF18 = pd.concat([mergeDF17, dataframe18])
mergeDF19 = pd.concat([mergeDF18, dataframe19])
mergeDF20 = pd.concat([mergeDF19, dataframe20])
mergeDF21 = pd.concat([mergeDF20, dataframe21])
mergeDF22 = pd.concat([mergeDF21, dataframe22])
mergeDF23 = pd.concat([mergeDF22, dataframe23])
mergeDF24 = pd.concat([mergeDF23, dataframe24])
mergeDF25 = pd.concat([mergeDF24, dataframe25])

# %%
# Sort it
mergeDF25.columns = ['Dependency Pair', 'Co-Occurences']
finalDF = mergeDF25.sort_values(by=['Co-Occurences'], ascending=False)
display(finalDF)
# Out:
#                                Dependency Pair Co-Occurences
# 11098                      node-sass@react-dom            99
# 3445                    devtron@electron-debug            99
# 882                              jquery@lodash            99
# 4236                            mobx@react-dom            99
# 3106           font-awesome@react-router-redux            99
# ...                                        ...           ...
# 95                                 qrcode@uuid            10
# 4558     codemirror/commands@codemirror/gutter            10
# 4560    codemirror/commands@codemirror/history            10
# 4563   codemirror/commands@codemirror/language            10
# 2988                    jszip@react-router-dom            10
#
# [134992 rows x 2 columns]

# %%
# Save as a CSV
import os

filename = "coOccurenceCounts.csv"

finalDF.to_csv('/content/drive/MyDrive/CPSC 572 Project/Data/' + filename, sep='\t', index=False)
if os.path.isfile('/content/drive/MyDrive/CPSC 572 Project/Data/' + filename):
  print(f"Successfully uploaded {filename} to /content/drive/MyDrive/CPSC 572 Project/Data/")
else:
  print(f"ERROR: Download unsuccessful for {filename} to /content/drive/MyDrive/CPSC 572 Project/Data/")
# Out:
# Successfully uploaded coOccurenceCounts.csv to /content/drive/MyDrive/CPSC 572 Project/Data/
